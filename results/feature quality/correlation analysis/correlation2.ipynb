# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-

import pandas
import matplotlib.pyplot as plt

from string import ascii_letters
import seaborn as sns
import pandas as pd
import numpy as np

sns.set(style='ticks')

# %%
rs = np.random.RandomState(0)
data = pd.read_csv("__feature_eval_1517.csv")[["rp","rh","bh","js","skl","mfcc","chroma","notes","agg"]]
corr = data.corr()
corr.style.background_gradient(cmap='coolwarm', low=0.5, axis=None)
# Out:
# <style  type="text/css" >
#     #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow0_col1 {
#             background-color:  #c53334;
#             color:  #f1f1f1;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow0_col2 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow0_col3 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow0_col4 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow0_col5 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow0_col6 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow0_col7 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow0_col8 {
#             background-color:  #e36c55;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow1_col0 {
#             background-color:  #c53334;
#             color:  #f1f1f1;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow1_col2 {
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow1_col3 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow1_col4 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow1_col5 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow1_col6 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow1_col7 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow1_col8 {
#             background-color:  #e16751;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow2_col0 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow2_col1 {
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow2_col3 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow2_col4 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow2_col5 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow2_col6 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow2_col7 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow2_col8 {
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow3_col0 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow3_col1 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow3_col2 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow3_col4 {
#             background-color:  #e16751;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow3_col5 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow3_col6 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow3_col7 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow3_col8 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow4_col0 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow4_col1 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow4_col2 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow4_col3 {
#             background-color:  #e16751;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow4_col5 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow4_col6 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow4_col7 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow4_col8 {
#             background-color:  #f7af91;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow5_col0 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow5_col1 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow5_col2 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow5_col3 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow5_col4 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow5_col6 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow5_col7 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow5_col8 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow6_col0 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow6_col1 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow6_col2 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow6_col3 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow6_col4 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_1f9bf560_af86_11e9_a956_1f63f1bd32afrow6_col5 {
#             background-color:  #d5dbe5;
#             color:  #000000;

# %%
corr = data.corr()
corr.style.background_gradient(cmap='PRGn', axis=None)
# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11,11))
plt.rcParams.update({'font.size': 12})
plt.title('Correlation of features, 95 songs (5 per genre), 1517 artists')

sns.heatmap(corr, cmap=cmap,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values, 
            vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
import matplotlib.pyplot as plt

data.plot(kind='scatter',x='rp',y='rh',color='red')
plt.show()

plt.figure()

data.plot(kind='scatter',x='rh',y='bh',color='blue')
plt.show()

# %%
data = pd.read_csv("__feature_eval_1517.csv")[["genre", "rp","rh","bh","js","skl","mfcc","chroma","notes","agg"]]

plt.figure()

fg = sns.FacetGrid(data=data, hue='genre', aspect=1.61)
fg.map(plt.scatter, 'agg','rp').add_legend()

plt.show()

# %%
import pandas as pd
data = pd.read_csv("__feature_eval_1517.csv")[["genre", "rp","rh","bh","js","skl","mfcc","chroma","notes","agg"]]
pd.plotting.scatter_matrix(data, alpha = 0.3, figsize = (20,20), diagonal='kde');
plt.show()

# %%
#https://pandas.pydata.org/pandas-docs/version/0.16.0/visualization.html

# %%
plt.figure()
data = pd.read_csv("__feature_eval_singlesong.csv")[["genre", "rp","rh","bh","js","skl","mfcc","chroma","notes","agg"]]
pd.plotting.scatter_matrix(data, alpha = 0.3, figsize = (20,20), diagonal='hist');
plt.show()

# %%
import seaborn as sns
data = pd.read_csv("__feature_eval_singlesong.csv")[["genre", "rp","rh","bh","js","skl","mfcc","chroma","notes","agg"]]
data = data.loc[(data['genre'] == "NewAge") | (data['genre'] == "Rock&Pop")| (data['genre'] == "Hip-Hop")] 

#data = (data[['genre']] == ('New Age' or 'Electronic&Dance' or 'Folk' or 'Comedy&SpokenWord'))
sns.set(style="ticks")
sns.pairplot(data, hue="genre")

# %%
import seaborn as sns
data = pd.read_csv("__feature_eval_single1517r.csv")[["genre", "rp","rh","bh","js","skl","mfcc","chroma","notes","agg"]]
data = data.loc[(data['genre'] == "Classical") | (data['genre'] == "Rock&Pop")| (data['genre'] == "Hip-Hop")] 
#data = (data[['genre']] == ('New Age' or 'Electronic&Dance' or 'Folk' or 'Comedy&SpokenWord'))
sns.set(style="ticks")
sns.pairplot(data, hue="genre")

# %%
sns.pairplot(x_vars="skl", y_vars="js", height=10, aspect=.8, hue="genre", data=data, kind="reg");

# %%
import seaborn as sns
data = pd.read_csv("__feature_eval_single100.csv")[["genre","rp","mfcc","chroma","bh"]]
data = data.loc[(data['genre'] == "Klassik")|(data['genre'] == "Pop")|(data['genre'] == "Metal")| (data['genre'] == "HipHop")|(data['genre'] == "Soundtrack")] 
#data = (data[['genre']] == ('New Age' or 'Electronic&Dance' or 'Folk' or 'Comedy&SpokenWord'))
sns.set(style="ticks")
sns.pairplot(data, height=3, hue="genre")
